# %% [markdown]
# ## Overview
# Clean BenefitCosxtSharing by Handle missing value and Sepatate file between $, numeric and string

# %% [markdown]
# ### Objectives
# 1. Loading and inspecting dataset
# 2. Select particular BusinessYear 2014
# 3. Select only the columns that you want to analyze
# 4. Separate the string to find groups of string
# 5. Information used in Two-way ANOVA
# 6. Handle this data
# 7. Find out Mean of Copay
# 8. Drop Duplicates values

# %% [markdown]
# ### 1. Loading and inspecting dataset
# #### import library
# 1. pandas that it allows you to create, manipulate, and analyze datasets efficiently.
# 2. numpy that it provides support for arrays, matrices, and various mathematical functions.
# 3. seaborn that it provides high-level functions to create attractive and informative plots.
# 4. matplotlib is a foundational library for creating static, interactive, and animated visualizations.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df_bcs = pd.read_csv("BenefitsCostSharing.csv",low_memory=False)

# %%
# inspect the dataset
df_bcs.shape
# Out:
# (5048408, 32)

# %%
# Countns BusinessYear
df_bcs['BusinessYear'].value_counts().reset_index()
# Out:
#    BusinessYear    count
# 0          2015  2079286
# 1          2016  1804253
# 2          2014  1164869

# %% [markdown]
# ### 2. Select particular BusinessYear 2014
# 1. Accesses the column BusinessYear from the DataFrame df_bcs2014
# 3. Counts the occurrences of each unique value in the BusinessYear column
# 4. Resets the index of the Series so that the unique values and their counts become columns in the new DataFrame

# %%
# Keep BusinessYear 2014 in df_bcs2014
df_bcs2014 = df_bcs[df_bcs['BusinessYear'] == 2014]

# %%
# 1,164,869 records
df_bcs2014['BusinessYear'].value_counts().reset_index()
# Out:
#    BusinessYear    count
# 0          2014  1164869

# %%
## display all columns
pd.set_option('display.max_columns',None)
# display first 5 rows
df_bcs2014.head()
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014           20%           NaN
# 1     Dental Check-Up for Children          2014           20%           NaN
# 2        Basic Dental Care - Child          2014           40%           NaN
# 3              Orthodontia - Child          2014           50%           NaN
# 4        Major Dental Care - Child          2014           50%           NaN
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
# 2           40%     No Charge           NaN     No Charge
# 3           50%     No Charge           NaN     No Charge
# 4           50%     No Charge           NaN     No Charge
#
#              EHBVarReason Exclusions  \
# 0               Above EHB        NaN
# 1     Substantially Equal        NaN
# 2     Substantially Equal        NaN
# 3  Additional EHB Benefit        NaN
# 4     Substantially Equal        NaN
#
#                                          Explanation           ImportDate  \
# 0  Combined annual benefit maximum of $1000 per y...  2014-03-19 07:06:49
# 1              See policy for additional limitations  2014-03-19 07:06:49
# 2              See policy for additional limitations  2014-03-19 07:06:49
# 3  24 month waiting period, See policy for additi...  2014-03-19 07:06:49
# 4              See policy for additional limitations  2014-03-19 07:06:49
#
#   IsCovered IsEHB IsExclFromInnMOOP IsExclFromOonMOOP IsStateMandate  \
# 0   Covered   NaN                No                No            NaN
# 1   Covered   Yes                No                No            NaN
# 2   Covered   Yes                No                No            NaN
# 3   Covered   NaN                No                No            NaN
# 4   Covered   Yes                No                No            NaN
#
#   IsSubjToDedTier1 IsSubjToDedTier2  IssuerId  IssuerId2  LimitQty  \
# 0               No               No     21989      21989    1000.0
# 1               No               No     21989      21989       1.0
# 2              Yes              Yes     21989      21989       NaN
# 3              Yes              Yes     21989      21989       NaN
# 4              Yes              Yes     21989      21989       NaN
#
#                LimitUnit  MinimumStay             PlanId QuantLimitOnSvc  \
# 0       Dollars per Year          NaN  21989AK0010001-00             Yes
# 1  Visit(s) per 6 Months          NaN  21989AK0010001-00             Yes
# 2                    NaN          NaN  21989AK0010001-00             NaN
# 3                    NaN          NaN  21989AK0010001-00             NaN
# 4                    NaN          NaN  21989AK0010001-00             NaN
#
#    RowNumber SourceName StandardComponentId StateCode StateCode2  VersionNum
# 0         68       HIOS      21989AK0010001        AK         AK           6
# 1        104       HIOS      21989AK0010001        AK         AK           6
# 2        110       HIOS      21989AK0010001        AK         AK           6
# 3        111       HIOS      21989AK0010001        AK         AK           6
# 4        112       HIOS      21989AK0010001        AK         AK           6

# %%
# inspect the dataset
df_bcs2014.shape
# Out:
# (1164869, 32)

# %% [markdown]
# ### 3. Select only the columns that you want to analyze
# 1. Select 'StandardComponentId','BenefitName','CopayInnTier1' columns.
# 2. Check 'CopayInnTier1' Column for to calculate copay value.

# %%
#Select only the columns you want to variable df_c1
df_c1 = df_bcs2014[['StandardComponentId','BenefitName','CopayInnTier1']]

# %%
## display all columns
pd.set_option('display.max_columns',None)
df_c1.head()
# Out:
#   StandardComponentId                      BenefitName CopayInnTier1
# 0      21989AK0010001  Routine Dental Services (Adult)     No Charge
# 1      21989AK0010001     Dental Check-Up for Children     No Charge
# 2      21989AK0010001        Basic Dental Care - Child     No Charge
# 3      21989AK0010001              Orthodontia - Child     No Charge
# 4      21989AK0010001        Major Dental Care - Child     No Charge

# %%
# display all columns, Non-Null Count and Dtype
df_c1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1164869 entries, 0 to 1164868
# Data columns (total 3 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   StandardComponentId  1164869 non-null  object
#  1   BenefitName          1164869 non-null  object
#  2   CopayInnTier1        898756 non-null   object
# dtypes: object(3)
# memory usage: 35.5+ MB

# %%
# display first 5 rows
df_c1.head()
# Out:
#   StandardComponentId                      BenefitName CopayInnTier1
# 0      21989AK0010001  Routine Dental Services (Adult)     No Charge
# 1      21989AK0010001     Dental Check-Up for Children     No Charge
# 2      21989AK0010001        Basic Dental Care - Child     No Charge
# 3      21989AK0010001              Orthodontia - Child     No Charge
# 4      21989AK0010001        Major Dental Care - Child     No Charge

# %% [markdown]
# ### 4. Separate the string to find groups of string
# 1. Separate numbers from CopayInnTier1 and store it in Copayment
# 2. Remove the number part from CopayInnTier1 and keep only the description (Description)
# 3. Clean NaN or empty values.
# 4. Convert amount_in_usd provided as a number (float) for further analysis.

# %%
# Separate into 'Amount' and 'Description'
df_c1['Copay'] = df_c1['CopayInnTier1'].str.extract(r'\$([\d,]+)')
df_c1['Description'] = df_c1['CopayInnTier1'].str.replace(r'\$[\d,]+\s?', '', regex=True)

# Replace 'nan' or empty strings with NaN for clarity
df_c1['Copay'] = df_c1['Copay'].str.replace(',', '').fillna('NaN')  # Remove commas for numerical conversion
df_c1['Description'] = df_c1['Description'].replace({'': 'NaN', 'nan': 'NaN'})
# Out:
# /var/folders/kc/wzqlm10x69xgkrpv4q3bp89w0000gn/T/ipykernel_2696/3523515561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c1['Copay'] = df_c1['CopayInnTier1'].str.extract(r'\$([\d,]+)')
# /var/folders/kc/wzqlm10x69xgkrpv4q3bp89w0000gn/T/ipykernel_2696/3523515561.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c1['Description'] = df_c1['CopayInnTier1'].str.replace(r'\$[\d,]+\s?', '', regex=True)
# /var/folders/kc/wzqlm10x69xgkrpv4q3bp89w0000gn/T/ipykernel_2696/3523515561.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c1['Copay'] = df_c1['Copay'].str.replace(',', '').fillna('NaN')  # Remove commas for numerical conversion
# /var/folders/kc/wzqlm10x69xgkrpv4q3bp89w0000gn/T/ipykernel_2696/3523515561.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c1['Description'] = df_c1['Description'].replace({'': 'NaN', 'nan': 'NaN'})

# %%
# display first 5 rows
df_c1.head()
# Out:
#   StandardComponentId                      BenefitName CopayInnTier1 Copay  \
# 0      21989AK0010001  Routine Dental Services (Adult)     No Charge   NaN
# 1      21989AK0010001     Dental Check-Up for Children     No Charge   NaN
# 2      21989AK0010001        Basic Dental Care - Child     No Charge   NaN
# 3      21989AK0010001              Orthodontia - Child     No Charge   NaN
# 4      21989AK0010001        Major Dental Care - Child     No Charge   NaN
#
#   Description
# 0   No Charge
# 1   No Charge
# 2   No Charge
# 3   No Charge
# 4   No Charge

# %% [markdown]
# ### 5. Information used in Two-way ANOVA
# The dependent variable must be quantitative in order to be able to analyze differences in means between groups. Therefore, the data in the example you provide must be adjusted or manipulated to provide a suitable numerical value for analysis.
#
# #### 5.1 Understanding Copay Information
# From the information you have:
# 1. No Charge and No Charge after deductible: indicates that there is no charge. or not waste money
# 2. NaN: May mean missing or unknown data.
# 3. `$10` Copay after deductible, `$10` Copay before deductible, `$10` Copay per Day, `$10` Copay per Stay: should be converted to numbers that can be analyzed statistically.
#
# #### 5.2 Handle non-numeric values
# 1. `$10, $500, $500`: Numbers are values that should be converted to numbers (0.10, 250, or 500, etc.).
# 2. No Charge / No Charge after deductible: should be converted to 0.
# 3. NaN: Show missing information. It can be drop because we don't domain expert.
# 4. 0%: Should be converted to 0.
# 5. Text formats such as after deductible or per Day should be separated or omitted if they are not relevant to the numbers.
#
# #### Copay after deductible, Copay per Day, Copay before deductible, Copay per Stay. It has no effect because in the end you will have to pay the displayed amount anyway. It can be drop.

# %%
# Check Desciption values
value_counts = df_c1['Description'].value_counts().reset_index(name='Count')
value_counts
# Out:
#                   Description   Count
# 0                   No Charge  465861
# 1                         NaN  309579
# 2  No Charge after deductible   54502
# 3      Copay after deductible   28789
# 4               Copay per Day   14754
# 5     Copay before deductible   13662
# 6              Copay per Stay    9867
# 7                          0%    1742

# %% [markdown]
# ### 6. Handle this data
# 1. Replace No Charge, No Charge after deductible, 0% in Description columns = 0 in Copayment columns
# 2. Drop NaN in Decriptions columns

# %%
# Remove NaN 309579 records from 898756 = 589177
# Step1: Replace 'No Charge', 'No Charge after deductible', '0%' in Description to Copayment is 0
df_c1.loc[df_c1['Description'].isin(['No Charge', 'No Charge after deductible', '0%']), 'Copay'] = '0'

# Step2: Drop 'NaN' in Copayment columns
df_c1 = df_c1[df_c1['Description'] != 'NaN'].reset_index(drop=True)

# %%
# Check value where not duplicate value 'Copayment' column
df_c1_uni = df_c1['Copay'].unique()
df_c1_uni
# Out:
# array(['0', 'NaN', '35', '50', '20', '150', '200', '300', '75', '10',
#        '70', '500', '60', '1000', '250', '15', '40', '1400', '100', '72',
#        '800', '600', '55', '25', '30', '1500', '9', '6', '4000', '5', '2',
#        '750', '4', '16', '350', '875', '17', '2200', '12', '2000', '1250',
#        '3', '45', '110', '85', '125', '375', '65', '3000', '4500', '700',
#        '2100', '120', '90', '80', '400', '7', '31', '190', '130', '950',
#        '95', '8', '38', '76', '175', '57', '18', '280', '275', '105',
#        '140', '1200', '550', '650', '210', '2500', '900', '43', '196',
#        '450'], dtype=object)

# %%
# Check value where not duplicate value 'Description' column
df_c1_uni2 = df_c1['Description'].unique()
df_c1_uni2
# Out:
# array(['No Charge', nan, 'Copay per Day', 'Copay before deductible',
#        'Copay after deductible', 'Copay per Stay',
#        'No Charge after deductible', '0%'], dtype=object)

# %%
# Drop nan in 'Description' Columns, reset index and drop old index by not keep be columns in DataFrame
df_c1 = df_c1.dropna(subset=['Description']).reset_index(drop=True)

# %%
# Check value where not duplicate value 'Description' column again after Drop nan
df_c1_uni3 = df_c1['Description'].unique()
df_c1_uni3
# Out:
# array(['No Charge', 'Copay per Day', 'Copay before deductible',
#        'Copay after deductible', 'Copay per Stay',
#        'No Charge after deductible', '0%'], dtype=object)

# %%
# Covert 'Copay' column to numeric
df_c1['Copay'] = pd.to_numeric(df_c1['Copay'], errors='coerce')

# %%
# Check value where not duplicate value 'Copay' column
df_c1_uni4 = df_c1['Copay'].unique()
df_c1_uni4
# Out:
# array([   0,   35,   50,   20,  150,  200,  300,   75,   10,   70,  500,
#          60, 1000,  250,   15,   40, 1400,  100,   72,  800,  600,   55,
#          25,   30, 1500,    9,    6, 4000,    5,    2,  750,    4,   16,
#         350,  875,   17, 2200,   12, 2000, 1250,    3,   45,  110,   85,
#         125,  375,   65, 3000, 4500,  700, 2100,  120,   90,   80,  400,
#           7,   31,  190,  130,  950,   95,    8,   38,   76,  175,   57,
#          18,  280,  275,  105,  140, 1200,  550,  650,  210, 2500,  900,
#          43,  196,  450])

# %%
# display first 5 rows
df_c1.head()
# Out:
#   StandardComponentId                      BenefitName CopayInnTier1  Copay  \
# 0      21989AK0010001  Routine Dental Services (Adult)     No Charge      0
# 1      21989AK0010001     Dental Check-Up for Children     No Charge      0
# 2      21989AK0010001        Basic Dental Care - Child     No Charge      0
# 3      21989AK0010001              Orthodontia - Child     No Charge      0
# 4      21989AK0010001        Major Dental Care - Child     No Charge      0
#
#   Description
# 0   No Charge
# 1   No Charge
# 2   No Charge
# 3   No Charge
# 4   No Charge

# %%
# display all columns, Non-Null Count and Dtype
df_c1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589177 entries, 0 to 589176
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   StandardComponentId  589177 non-null  object
#  1   BenefitName          589177 non-null  object
#  2   CopayInnTier1        589177 non-null  object
#  3   Copay                589177 non-null  int64
#  4   Description          589177 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 22.5+ MB

# %% [markdown]
# ### 7. Find out Mean of Copay
# 1. Find out Mean of Copayment each PlanId and Add new columns Mean Copayment for check each PlanId have how mean of Copayment
# 2. Check manual
# 3. Calculate the Mean of each PlanId and take the resulting Mean file and add it as a new Column after the Description column by inserting the reference value from the original PlanId
# 4. Check Mean_Copayment of StandardComponentId that you want

# %%
# Step1: Find out Copayment > 0 for test find out mean value of PlanId
plans_with_copayment = df_c1[df_c1['Copay'] > 0]['StandardComponentId'].unique()
plans_with_copayment
# Out:
# array(['44580AL0360001', '44580AL0360003', '44580AL0360004', ...,
#        '31274WV0350002', '31274WV0420021', '31274WV0420031'], dtype=object)

# %%
# Step2: Check manual
# Filtered PlanId is 31274WV0420031 (Example)
filtered_df = df_c1[df_c1['StandardComponentId'] == '31274WV0420031']

# Count all value of Copayment
copayment_count = filtered_df['Copay'].notna().sum()

# Find valure that not duplicate value in Copayment and number of value
copayment_value_counts = filtered_df['Copay'].value_counts().reset_index()
copayment_value_counts.columns = ['Copay', 'Count']

# Calculate Mean of Copayment
copayment_mean = filtered_df['Copay'].mean()

# Display recheck mean value of 31274WV0420031
print(f"all Copayment values: {copayment_count}")
print("Values in Copay:")
print(copayment_value_counts)
print(f"Mean of Copayment: {copayment_mean:.2f}")

#Check manual 31274WV0420031 = (35+35+35)/55 = 1.91 Mean
# Out:
# all Copayment values: 55
# Values in Copay:
#    Copay  Count
# 0      0     52
# 1     35      3
# Mean of Copayment: 1.91

# %%
# Step3: Calculate Mean of Copayment for each PlanId
mean_copayment_per_plan = df_c1.groupby('StandardComponentId')['Copay'].mean().reset_index(name='Copayment')

# Merge the Mean value back into the original DataFrame
df_with_mean = pd.merge(df_c1, mean_copayment_per_plan, on='StandardComponentId', how='left')

# Reorder columns to be after Description
columns_order = df_c1.columns.tolist() + ['Copayment']
df_with_mean = df_with_mean[columns_order]

# Display first 5 rows
df_with_mean.head()
# Out:
#   StandardComponentId                      BenefitName CopayInnTier1  Copay  \
# 0      21989AK0010001  Routine Dental Services (Adult)     No Charge      0
# 1      21989AK0010001     Dental Check-Up for Children     No Charge      0
# 2      21989AK0010001        Basic Dental Care - Child     No Charge      0
# 3      21989AK0010001              Orthodontia - Child     No Charge      0
# 4      21989AK0010001        Major Dental Care - Child     No Charge      0
#
#   Description  Copayment
# 0   No Charge        0.0
# 1   No Charge        0.0
# 2   No Charge        0.0
# 3   No Charge        0.0
# 4   No Charge        0.0

# %%
# display all columns, Non-Null Count and Dtype
df_with_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 
# 588719                    No Charge      0                No Charge   1.909091
# 588720                    No Charge      0                No Charge   1.909091
# 588721                    No Charge      0                No Charge   1.909091
# 588722                    No Charge      0                No Charge   1.909091
# 588723                    No Charge      0                No Charge   1.909091
# 588724                    No Charge      0                No Charge   1.909091
# 588725                    No Charge      0                No Charge   1.909091
# 588726                    No Charge      0                No Charge   1.909091
# 588727                    No Charge      0                No Charge   1.909091
# 588728                    No Charge      0                No Charge   1.909091
# 588729                    No Charge      0                No Charge   1.909091
# 588730                    No Charge      0                No Charge   1.909091

# %% [markdown]
# ### 8. Drop Duplicates values
# 1. Drop 'StandardComponentId' column with duplicate values
# 2. Create CSV file

# %%
#drop duplicates values keep in df_no_duplicates
df_no_duplicates = df_with_mean.drop_duplicates(subset=["StandardComponentId"])
df_no_duplicates
# Out:
#        StandardComponentId                      BenefitName CopayInnTier1  \
# 0           21989AK0010001  Routine Dental Services (Adult)     No Charge
# 14          21989AK0020001  Routine Dental Services (Adult)     No Charge
# 28          21989AK0020002  Routine Dental Services (Adult)     No Charge
# 42          38536AK0010002        Major Dental Care - Adult     No Charge
# 45          38536AK0010003  Routine Dental Services (Adult)     No Charge
# ...                    ...                              ...           ...
# 589108      96480WV0060001  Routine Dental Services (Adult)     No Charge
# 589131      96480WV0080001  Routine Dental Services (Adult)     No Charge
# 589147      96480WV0090001  Routine Dental Services (Adult)     No Charge
# 589161      96480WV0100001     Dental Check-Up for Children     No Charge
# 589169      96480WV0110001     Dental Check-Up for Children     No Charge
#
#         Copayment Description  Mean_Copayment
# 0               0   No Charge             0.0
# 14              0   No Charge             0.0
# 28              0   No Charge             0.0
# 42              0   No Charge             0.0
# 45              0   No Charge             0.0
# ...           ...         ...             ...
# 589108          0   No Charge             0.0
# 589131          0   No Charge             0.0
# 589147          0   No Charge             0.0
# 589161          0   No Charge             0.0
# 589169          0   No Charge             0.0
#
# [6549 rows x 6 columns]

# %%
# display all columns, Non-Null Count and Dtype
df_no_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6549 entries, 0 to 589169
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   StandardComponentId  6549 non-null   object
#  1   BenefitName          6549 non-null   object
#  2   CopayInnTier1        6549 non-null   object
#  3   Copayment            6549 non-null   int64
#  4   Description          6549 non-null   object
#  5   Mean_Copayment       6549 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 358.1+ KB

# %%
# display first 5 rows
df_no_duplicates.head()
# Out:
#    StandardComponentId                      BenefitName CopayInnTier1  \
# 0       21989AK0010001  Routine Dental Services (Adult)     No Charge
# 14      21989AK0020001  Routine Dental Services (Adult)     No Charge
# 28      21989AK0020002  Routine Dental Services (Adult)     No Charge
# 42      38536AK0010002        Major Dental Care - Adult     No Charge
# 45      38536AK0010003  Routine Dental Services (Adult)     No Charge
#
#     Copayment Description  Mean_Copayment
# 0           0   No Charge             0.0
# 14          0   No Charge             0.0
# 28          0   No Charge             0.0
# 42          0   No Charge             0.0
# 45          0   No Charge             0.0

# %%
#create csv after clean BenefitCostSharing no duplicates
df_no_duplicates.to_csv('clean_benefitcostsharing_mean_no_duplicates.csv')
